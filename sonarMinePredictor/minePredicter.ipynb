# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset into panda's dataframe 
sonar_data = pd.read_csv('/content/sonar data.csv', header=None)

# %%
sonar_data.head()
# Out:
#        0       1       2       3       4   ...      56      57      58      59  60
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032   R
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044   R
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078   R
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  ...  0.0050  0.0044  0.0040  0.0117   R
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  ...  0.0072  0.0048  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
#finding the mean 
sonar_data.groupby(60).mean()
# Out:
#           0         1         2   ...        57        58        59
# 60                                ...
# M   0.034989  0.045544  0.050720  ...  0.009060  0.008695  0.006930
# R   0.022498  0.030303  0.035951  ...  0.006677  0.007078  0.006024
#
# [2 rows x 60 columns]

# %%
# seperating data and labels 
x = sonar_data.drop(columns= 60 , axis = 1)
y = sonar_data[60]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.1 , stratify= y , random_state = 1)

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
x_train_predection = model.predict(x_test)
training_data_Accuracy = accuracy_score(x_train_predection, y_test)
training_data_Accuracy
# Out:
# 0.7619047619047619

# %%
# generating a predective system 
input_data = [0.0453,0.0523,0.0843,0.0689,0.1183,0.2583,0.2156,0.3481,0.3337,0.2872,0.4918,0.6552,0.6919,0.7797,0.7464,0.9444,1.0000,0.8874,0.8024,0.7818,0.5212,0.4052,0.3957,0.3914,0.3250,0.3200,0.3271,0.2767,0.4423,0.2028,0.3788,0.2947,0.1984,0.2341,0.1306,0.4182,0.3835,0.1057,0.1840,0.1970,0.1674,0.0583,0.1401,0.1628,0.0621,0.0203,0.0530,0.0742,0.0409,0.0061,0.0125,0.0084,0.0089,0.0048,0.0094,0.0191,0.0140,0.0049,0.0052,0.0044]
input_data_numpy  = np.asarray(input_data)
input_data_reshape = input_data_numpy.reshape(1,-1)
prediction = model.predict(input_data_reshape)
if(prediction[0] == 'R'):
  print('its safe to move ahead!!')
else:
  print('mines ahead!')
# Out:
# its safe to move ahead!!
